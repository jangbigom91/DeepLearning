# %% [markdown]
# ## 딥러닝

# %% [markdown]
# #### Sequential( ) 함수는 딥러닝의 구조를 한 층 한 층 쉽게 쌓아올릴 수 있게 해 줌
# #### Sequential( ) 함수를 선언하고 나서 model.add( ) 함수를 사용해 필요한 층을
# #### 차례로 추가하면 됨

# %% [markdown]
# #### 케라스의 가장 큰 장점 중 하나는 model.add( ) 함수를 이용해 필요한 만큼의 층을
# #### 빠르고 쉽게 쌓아 올릴 수 있다는 것

# %% [markdown]
# #### model.add( ) 함수안에는 Dense( ) 함수가 포함되어 있음
# #### dense는 ‘조밀하게 모여있는 집합’이란 뜻으로, 각 층이 제각각 어떤 특성을 가질지 옵션을 설정하는 역할

# %% [markdown]
# #### - activation : 다음 층으로 어떻게 값을 넘길지 결정하는 부분
# #### 가장 많이 사용되는 함수 : relu() 함수, sigmoid() 함수
# #### - loss : 한 번 신경망이 실행될 때마다 오차 값을 추적하는 함수
# #### - optimizer : 오차를 어떻게 줄여 나갈지 정하는 함수

# %%
# 딥러닝을 구동하는데 필요한 케라스 함수를 불러옵니다.
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# 필요한 라이브러리를 불러옵니다.
import numpy as np
import tensorflow as tf

# 실행할 때마다 같은 결과를 출력하기 위해 설정하는 부분입니다.
np.random.seed(3)
tf.random.set_seed(3)
# Out:
# (470, 18)

# %%
# 준비된 수술 환자 데이터를 불러들입니다.
Data_set = np.loadtxt("ThoraricSurgery.csv", delimiter=",")
Data_set.shape

# 환자의 기록과 수술결과를 X와 Y로 구분하여 저장합니다.
X = Data_set[:, 0:17]
Y = Data_set[:, 17]

# %%
# 딥러닝 구조를 결정합니다.(모델을 설정하고 실행하는 부분입니다.)
model = Sequential() # 신경망 생성신경망 생성
model.add(Dense(30, input_dim=17, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# 딥러닝을 실행합니다.
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(X, Y, epochs=100, batch_size=10)
# Out:
# Epoch 1/100
# 47/47 [==============================] - 0s 474us/step - loss: 0.8781 - accuracy: 0.7774
# Epoch 2/100
# 47/47 [==============================] - 0s 477us/step - loss: 0.4637 - accuracy: 0.8707
# Epoch 3/100
# 47/47 [==============================] - 0s 477us/step - loss: 0.4652 - accuracy: 0.8347
# Epoch 4/100
# 47/47 [==============================] - 0s 522us/step - loss: 0.5176 - accuracy: 0.8405
# Epoch 5/100
# 47/47 [==============================] - 0s 478us/step - loss: 0.4461 - accuracy: 0.8570
# Epoch 6/100
# 47/47 [==============================] - 0s 476us/step - loss: 0.4391 - accuracy: 0.8523
# Epoch 7/100
# 47/47 [==============================] - 0s 477us/step - loss: 0.4616 - accuracy: 0.8443
# Epoch 8/100
# 47/47 [==============================] - 0s 477us/step - loss: 0.4523 - accuracy: 0.8447
# Epoch 9/100
# 47/47 [==============================] - 0s 456us/step - loss: 0.3877 - accuracy: 0.8618
# Epoch 10/100
# ...

# %%
# 딥러닝을 구동하는데 필요한 케라스 함수를 불러옵니다.
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# 필요한 라이브러리를 불러옵니다.
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

# 가상적인 데이터 생성
X = data =  np.linspace(1,2,200) # 시작값=1, 종료값=2, 개수=200
# X.shape
y = X * 4 + np.random.randn(200)*0.3 # X를 4배로 하고 편차 0.3정도의 가우시안 잡음추가
# Y

model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Dense(1, input_dim=1, activation='linear'))
model.compile(optimizer='sgd', loss='mse', metrics=['mse'])
model.fit(X,Y, batch_size=1, epochs=30)

predict = model.predict(data)

plt.plot(data, predict, 'b', data, y, 'k.') # 첫번째 그래프는 파란색 마커로, # 두번째 그래프는 검정색. 으로 그린다.
plt.show()
# Out:
# Epoch 1/30
# 200/200 [==============================] - 0s 393us/step - loss: 4.0257 - mse: 4.0257
# Epoch 2/30
# 200/200 [==============================] - 0s 371us/step - loss: 0.2013 - mse: 0.2013
# Epoch 3/30
# 200/200 [==============================] - 0s 358us/step - loss: 0.1828 - mse: 0.1828
# Epoch 4/30
# 200/200 [==============================] - 0s 351us/step - loss: 0.1372 - mse: 0.1372
# Epoch 5/30
# 200/200 [==============================] - 0s 350us/step - loss: 0.1395 - mse: 0.1395
# Epoch 6/30
# 200/200 [==============================] - 0s 343us/step - loss: 0.1205 - mse: 0.1205
# Epoch 7/30
# 200/200 [==============================] - 0s 374us/step - loss: 0.1291 - mse: 0.1291
# Epoch 8/30
# 200/200 [==============================] - 0s 370us/step - loss: 0.1089 - mse: 0.1089
# Epoch 9/30
# 200/200 [==============================] - 0s 351us/step - loss: 0.1083 - mse: 0.1083
# Epoch 10/30
# ...
