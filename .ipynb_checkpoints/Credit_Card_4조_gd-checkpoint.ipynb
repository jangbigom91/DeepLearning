# %% [markdown]
# ### 4조 : 방형진, 이상욱, 최정한, 최형욱

# %% [markdown]
# ## import할 모듈

# %%
#-*- coding: utf-8 -*-
from keras.models import Sequential, load_model
from keras.layers import Dense
from keras.callbacks import ModelCheckpoint, EarlyStopping
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_curve, roc_auc_score,confusion_matrix, precision_recall_curve
from sklearn.preprocessing import StandardScaler, MinMaxScaler

import numpy
import os
import pandas as pd
import tensorflow as tf
import warnings
import matplotlib.pyplot as plt
import seaborn as sns
import graphviz
import time

warnings.filterwarnings('ignore')
# %matplotlib inline

# %% [markdown]
# ## CSV 파일 읽어오기, seed 값 설정

# %%
# seed 값 설정
seed = 0
numpy.random.seed(seed)
tf.random.set_seed(3)
df = pd.read_csv("creditcard.csv")

# %% [markdown]
# ## 1. 아무런 처리 없이 학습, 예측

# %%
df
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 0       0.462388  0.239599  0.098698  0.363787  ... -0.018307  0.277838
# 1      -0.082361 -0.078803  0.085102 -0.255425  ... -0.225775 -0.638672
# 2       1.800499  0.791461  0.247676 -1.514654  ...  0.247998  0.771679
# 3       1.247203  0.237609  0.377436 -1.387024  ... -0.108300  0.005274
# 4       0.095921  0.592941 -0.270533  0.817739  ... -0.009431  0.798278
# ...          ...       ...       ...       ...  ...       ...       ...
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# 0      -0.110474  0.066928  0.128539 -0.189115  0.133558 -0.021053  149.62
# 1       0.101288 -0.339846  0.167170  0.125895 -0.008983  0.014724    2.69
# 2       0.909412 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752  378.66
# 3      -0.190321 -1.175575  0.647376 -0.221929  0.062723  0.061458  123.50
# 4      -0.137458  0.141267 -0.206010  0.502292  0.219422  0.215153   69.99
# ...          ...       ...       ...       ...       ...       ...     ...
# 284802  1.014480 -0.509348  1.436807  0.250034  0.943651  0.823731    0.77
# 284803  0.012463 -1.016226 -0.606624 -0.395255  0.068472 -0.053527   24.79
# 284804 -0.037501  0.640134  0.265745 -0.087371  0.004455 -0.026561   67.88
# 284805 -0.163298  0.123205 -0.569159  0.546668  0.108821  0.104533   10.00
# 284806  0.376777  0.008797 -0.473649 -0.818267 -0.002415  0.013649  217.00
#
#         Class
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 284802      0
# 284803      0
# 284804      0
# 284805      0
# 284806      0
#
# [284807 rows x 31 columns]

# %%
plt.figure(figsize = (14,14))
plt.title('Credit Card Transactions features correlation plot (Pearson)')
corr = df.corr()
sns.heatmap(corr,xticklabels=corr.columns,yticklabels=corr.columns,linewidths=.1,cmap="Reds")
plt.show()

# %%
print('데이터 세트 Null 값 갯수 \n',df.isnull().sum())
# Out:
# 데이터 세트 Null 값 갯수
#  Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %% [markdown]
# ### CSV 데이터 종속, 독립 변수 분할

# %%
dataset = df.values     #읽어온 데이터를 분할하기위해 다시 변환
X = dataset[:,1:30]     #독립변수, time 칼럼을 빼기 위해 1부터 30까지 
Y = dataset[:,30]       #종속변수 
#훈련, 테스트 데이터 분할
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.15, random_state=3)    #test_size가 전체의 15%

# %% [markdown]
# #### 아래에서 input_dim을 바꾸지 않고 사용해서 에러가 계속 생겼었음

# %%
#모델 구조 생성 Dense 값들은 그냥 아무렇게나 준 것
model = Sequential()
model.add(Dense(30,  input_dim=29, activation='relu'))    #학습에 사용될 데이터의 열이 29개 이므로 input_dim을 29로 줌
model.add(Dense(15, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))    #최종 결과가 0아니면 1인 이진 분류이므로 sigmoid 사용

# %% [markdown]
# ### 모델 컴파일 및 학습

# %%
model.compile(loss='binary_crossentropy',
             optimizer='adam',
             metrics=['accuracy',tf.keras.metrics.Precision(name='precision'),tf.keras.metrics.Recall(name='recall')])
MODEL_DIR = './credit_model/'    #향후 다시 모델 사용할 때를 위한 모델 저장경로

if not os.path.exists(MODEL_DIR):
    os.mkdir(MODEL_DIR)
    
modelpath = './model/{epoch:02d}-{val_loss:.4f}.hdf5'
checkpointer = ModelCheckpoint(filepath = modelpath, monitor = 'val_loss', verbose = 1, save_best_only=True)

early_stopping_callback= EarlyStopping(monitor= 'val_loss', patience = 20) 
#한 번 학습에 시간이 오래 걸리기 때문에 중간 정지하는 patience를 20만 줘서 빨리 학습이 중단되도록 설정

history = model.fit(X_train, Y_train, validation_split=0.2, epochs=100, batch_size=100, callbacks = [early_stopping_callback,checkpointer])
#epoch와 batch_size또한 학습 시간을 줄이기 위해 epoch는 줄이고 batch_size는 늘림
# Out:
# Epoch 1/100
# 1937/1937 [==============================] - 2s 879us/step - loss: 0.0652 - accuracy: 0.9895 - precision: 0.1762 - recall: 0.3257 - val_loss: 0.0253 - val_accuracy: 0.9987 - val_precision: 0.8077 - val_recall: 0.4516
#
# Epoch 00001: val_loss improved from inf to 0.02527, saving model to ./model\01-0.0253.hdf5
# Epoch 2/100
# 1937/1937 [==============================] - 1s 763us/step - loss: 0.0084 - accuracy: 0.9994 - precision: 0.8535 - recall: 0.7549 - val_loss: 0.0078 - val_accuracy: 0.9993 - val_precision: 0.8625 - val_recall: 0.7419
#
# Epoch 00002: val_loss improved from 0.02527 to 0.00775, saving model to ./model\02-0.0078.hdf5
# Epoch 3/100
# 1937/1937 [==============================] - 1s 766us/step - loss: 0.0079 - accuracy: 0.9993 - precision: 0.8033 - recall: 0.7034 - val_loss: 0.0491 - val_accuracy: 0.9987 - val_precision: 0.8974 - val_recall: 0.3763
#
# Epoch 00003: val_loss did not improve from 0.00775
# Epoch 4/100
# 1937/1937 [==============================] - 1s 759us/step - loss: 0.0096 - accuracy: 0.9992 - precision: 0.8350 - recall: 0.6862 - val_loss: 0.0238 - val_accuracy: 0.9990 - val_precision: 0.9388 - val_recall: 0.4946
#
# Epoch 00004: val_loss did not improve from 0.00775
# Epoch 5/100
# 1937/1937 [==============================] - 1s 764us/step - loss: 0.0050 - accuracy: 0.9994 - precision: 0.8581 - recall: 0.7304 - val_loss: 0.0060 - val_accuracy: 0.9991 - val_precision: 0.9016 - val_recall: 0.5914
#
# Epoch 00005: val_loss improved from 0.00775 to 0.00601, saving model to ./model\05-0.0060.hdf5
# Epoch 6/100
# 1937/1937 [==============================] - 1s 751us/step - loss: 0.0062 - accuracy: 0.9994 - precision: 0.8939 - recall: 0.7545 - val_loss: 0.0115 - val_accuracy: 0.9990 - val_precision: 0.8615 - val_recall: 0.6022
#
# Epoch 00006: val_loss did not improve from 0.00601
# Epoch 7/100
# 1937/1937 [==============================] - 1s 746us/step - loss: 0.0045 - accuracy: 0.9993 - precision: 0.8500 - recall: 0.7108 - val_loss: 0.0047 - val_accuracy: 0.9992 - val_precision: 0.8732 - val_recall: 0.6667
#
# Epoch 00007: val_loss improved from 0.00601 to 0.00467, saving model to ./model\07-0.0047.hdf5
# Epoch 8/100
# 1937/1937 [==============================] - 1s 750us/step - loss: 0.0048 - accuracy: 0.9995 - precision: 0.9060 - recall: 0.7731 - val_loss: 0.0040 - val_accuracy: 0.9992 - val_precision: 0.8553 - val_recall: 0.6989
#
# Epoch 00008: val_loss improved from 0.00467 to 0.00403, saving model to ./model\08-0.0040.hdf5
# Epoch 9/100
# 1937/1937 [==============================] - 1s 768us/step - loss: 0.0028 - accuracy: 0.9995 - precision: 0.8837 - recall: 0.7619 - val_loss: 0.0043 - val_accuracy: 0.9994 - val_precision: 0.9306 - val_recall: 0.7204
#
# Epoch 00009: val_loss did not improve from 0.00403
# Epoch 10/100
# 1937/1937 [==============================] - 1s 721us/step - loss: 0.0026 - accuracy: 0.9996 - precision: 0.9229 - recall: 0.8189 - val_loss: 0.0053 - val_accuracy: 0.9993 - val_precision: 0.9254 - val_recall: 0.6667
#
# Epoch 00010: val_loss did not improve from 0.00403
# Epoch 11/100
# 1937/1937 [==============================] - 1s 733us/step - loss: 0.0025 - accuracy: 0.9996 - precision: 0.9243 - recall: 0.8010 - val_loss: 0.0073 - val_accuracy: 0.9993 - val_precision: 0.9552 - val_recall: 0.6882
#
# Epoch 00011: val_loss did not improve from 0.00403
# Epoch 12/100
# 1937/1937 [==============================] - 1s 730us/step - loss: 0.0032 - accuracy: 0.9995 - precision: 0.9381 - recall: 0.7660 - val_loss: 0.0043 - val_accuracy: 0.9993 - val_precision: 0.8904 - val_recall: 0.6989
#
# Epoch 00012: val_loss did not improve from 0.00403
# Epoch 13/100
# 1937/1937 [==============================] - 1s 743us/step - loss: 0.0036 - accuracy: 0.9995 - precision: 0.9096 - recall: 0.7729 - val_loss: 0.0044 - val_accuracy: 0.9994 - val_precision: 0.9459 - val_recall: 0.7527
#
# Epoch 00013: val_loss did not improve from 0.00403
# Epoch 14/100
# 1937/1937 [==============================] - 1s 736us/step - loss: 0.0032 - accuracy: 0.9995 - precision: 0.9205 - recall: 0.7428 - val_loss: 0.0048 - val_accuracy: 0.9995 - val_precision: 0.9351 - val_recall: 0.7742
#
# Epoch 00014: val_loss did not improve from 0.00403
# Epoch 15/100
# 1937/1937 [==============================] - 1s 736us/step - loss: 0.0032 - accuracy: 0.9994 - precision: 0.9141 - recall: 0.7585 - val_loss: 0.0040 - val_accuracy: 0.9994 - val_precision: 0.9221 - val_recall: 0.7634
#
# Epoch 00015: val_loss improved from 0.00403 to 0.00402, saving model to ./model\15-0.0040.hdf5
# Epoch 16/100
# 1937/1937 [==============================] - 1s 743us/step - loss: 0.0029 - accuracy: 0.9995 - precision: 0.9203 - recall: 0.7474 - val_loss: 0.0043 - val_accuracy: 0.9994 - val_precision: 0.9429 - val_recall: 0.7097
#
# Epoch 00016: val_loss did not improve from 0.00402
# Epoch 17/100
# 1937/1937 [==============================] - 1s 760us/step - loss: 0.0027 - accuracy: 0.9996 - precision: 0.9458 - recall: 0.8198 - val_loss: 0.0038 - val_accuracy: 0.9994 - val_precision: 0.9844 - val_recall: 0.6774
#
# Epoch 00017: val_loss improved from 0.00402 to 0.00381, saving model to ./model\17-0.0038.hdf5
# Epoch 18/100
# 1937/1937 [==============================] - 1s 753us/step - loss: 0.0029 - accuracy: 0.9995 - precision: 0.9437 - recall: 0.7756 - val_loss: 0.0044 - val_accuracy: 0.9994 - val_precision: 0.8875 - val_recall: 0.7634
#
# Epoch 00018: val_loss did not improve from 0.00381
# Epoch 19/100
# 1937/1937 [==============================] - 1s 732us/step - loss: 0.0026 - accuracy: 0.9995 - precision: 0.9095 - recall: 0.7825 - val_loss: 0.0039 - val_accuracy: 0.9993 - val_precision: 0.9420 - val_recall: 0.6989
#
# Epoch 00019: val_loss did not improve from 0.00381
# Epoch 20/100
# 1937/1937 [==============================] - 1s 734us/step - loss: 0.0022 - accuracy: 0.9996 - precision: 0.9509 - recall: 0.7940 - val_loss: 0.0049 - val_accuracy: 0.9994 - val_precision: 0.9459 - val_recall: 0.7527
#
# Epoch 00020: val_loss did not improve from 0.00381
# Epoch 21/100
# 1937/1937 [==============================] - 1s 724us/step - loss: 0.0020 - accuracy: 0.9997 - precision: 0.9659 - recall: 0.8398 - val_loss: 0.0037 - val_accuracy: 0.9995 - val_precision: 0.9467 - val_recall: 0.7634
#
# Epoch 00021: val_loss improved from 0.00381 to 0.00375, saving model to ./model\21-0.0037.hdf5
# Epoch 22/100
# 1937/1937 [==============================] - 1s 731us/step - loss: 0.0017 - accuracy: 0.9996 - precision: 0.9277 - recall: 0.8372 - val_loss: 0.0042 - val_accuracy: 0.9994 - val_precision: 0.9211 - val_recall: 0.7527
#
# Epoch 00022: val_loss did not improve from 0.00375
# Epoch 23/100
# 1937/1937 [==============================] - 1s 728us/step - loss: 0.0023 - accuracy: 0.9996 - precision: 0.9404 - recall: 0.7796 - val_loss: 0.0057 - val_accuracy: 0.9994 - val_precision: 0.9706 - val_recall: 0.7097
#
# Epoch 00023: val_loss did not improve from 0.00375
# Epoch 24/100
# 1937/1937 [==============================] - 1s 730us/step - loss: 0.0024 - accuracy: 0.9996 - precision: 0.9257 - recall: 0.8022 - val_loss: 0.0041 - val_accuracy: 0.9995 - val_precision: 0.9351 - val_recall: 0.7742
#
# Epoch 00024: val_loss did not improve from 0.00375
# Epoch 25/100
# 1937/1937 [==============================] - 1s 739us/step - loss: 0.0021 - accuracy: 0.9995 - precision: 0.9359 - recall: 0.8156 - val_loss: 0.0047 - val_accuracy: 0.9994 - val_precision: 0.9459 - val_recall: 0.7527
#
# Epoch 00025: val_loss did not improve from 0.00375
# Epoch 26/100
# 1937/1937 [==============================] - 1s 736us/step - loss: 0.0022 - accuracy: 0.9996 - precision: 0.9469 - recall: 0.8073 - val_loss: 0.0045 - val_accuracy: 0.9996 - val_precision: 0.9615 - val_recall: 0.8065
#
# Epoch 00026: val_loss did not improve from 0.00375
# Epoch 27/100
# 1937/1937 [==============================] - 1s 737us/step - loss: 0.0018 - accuracy: 0.9997 - precision: 0.9509 - recall: 0.8405 - val_loss: 0.0040 - val_accuracy: 0.9994 - val_precision: 0.9571 - val_recall: 0.7204
#
# Epoch 00027: val_loss did not improve from 0.00375
# Epoch 28/100
# 1937/1937 [==============================] - 1s 729us/step - loss: 0.0017 - accuracy: 0.9996 - precision: 0.9701 - recall: 0.8182 - val_loss: 0.0048 - val_accuracy: 0.9994 - val_precision: 0.9221 - val_recall: 0.7634
#
# Epoch 00028: val_loss did not improve from 0.00375
# Epoch 29/100
# 1937/1937 [==============================] - 1s 739us/step - loss: 0.0017 - accuracy: 0.9997 - precision: 0.9683 - recall: 0.8483 - val_loss: 0.0043 - val_accuracy: 0.9994 - val_precision: 0.9333 - val_recall: 0.7527
#
# Epoch 00029: val_loss did not improve from 0.00375
# Epoch 30/100
# 1937/1937 [==============================] - 1s 728us/step - loss: 0.0020 - accuracy: 0.9996 - precision: 0.9219 - recall: 0.7866 - val_loss: 0.0051 - val_accuracy: 0.9995 - val_precision: 0.9610 - val_recall: 0.7957
#
# Epoch 00030: val_loss did not improve from 0.00375
# Epoch 31/100
# 1937/1937 [==============================] - 1s 725us/step - loss: 0.0019 - accuracy: 0.9996 - precision: 0.9459 - recall: 0.8387 - val_loss: 0.0044 - val_accuracy: 0.9995 - val_precision: 0.9730 - val_recall: 0.7742
#
# Epoch 00031: val_loss did not improve from 0.00375
# Epoch 32/100
# 1937/1937 [==============================] - 1s 735us/step - loss: 0.0014 - accuracy: 0.9997 - precision: 0.9537 - recall: 0.8714 - val_loss: 0.0041 - val_accuracy: 0.9994 - val_precision: 0.9231 - val_recall: 0.7742
#
# Epoch 00032: val_loss did not improve from 0.00375
# Epoch 33/100
# 1937/1937 [==============================] - 1s 724us/step - loss: 0.0017 - accuracy: 0.9996 - precision: 0.9380 - recall: 0.8419 - val_loss: 0.0051 - val_accuracy: 0.9994 - val_precision: 0.9706 - val_recall: 0.7097
#
# Epoch 00033: val_loss did not improve from 0.00375
# Epoch 34/100
# 1937/1937 [==============================] - 1s 729us/step - loss: 0.0017 - accuracy: 0.9997 - precision: 0.9584 - recall: 0.8334 - val_loss: 0.0045 - val_accuracy: 0.9995 - val_precision: 0.9157 - val_recall: 0.8172
#
# Epoch 00034: val_loss did not improve from 0.00375
# Epoch 35/100
# 1937/1937 [==============================] - 1s 744us/step - loss: 0.0016 - accuracy: 0.9997 - precision: 0.9570 - recall: 0.8586 - val_loss: 0.0055 - val_accuracy: 0.9994 - val_precision: 0.9333 - val_recall: 0.7527
#
# Epoch 00035: val_loss did not improve from 0.00375
# Epoch 36/100
# 1937/1937 [==============================] - 1s 734us/step - loss: 0.0018 - accuracy: 0.9996 - precision: 0.9505 - recall: 0.8207 - val_loss: 0.0048 - val_accuracy: 0.9994 - val_precision: 0.9221 - val_recall: 0.7634
#
# Epoch 00036: val_loss did not improve from 0.00375
# Epoch 37/100
# 1937/1937 [==============================] - 1s 732us/step - loss: 0.0020 - accuracy: 0.9997 - precision: 0.9504 - recall: 0.8487 - val_loss: 0.0070 - val_accuracy: 0.9993 - val_precision: 0.9552 - val_recall: 0.6882
#
# Epoch 00037: val_loss did not improve from 0.00375
# Epoch 38/100
# 1937/1937 [==============================] - 1s 725us/step - loss: 0.0018 - accuracy: 0.9997 - precision: 0.9848 - recall: 0.8558 - val_loss: 0.0048 - val_accuracy: 0.9995 - val_precision: 0.9474 - val_recall: 0.7742
#
# Epoch 00038: val_loss did not improve from 0.00375
# Epoch 39/100
# 1937/1937 [==============================] - 1s 727us/step - loss: 0.0016 - accuracy: 0.9997 - precision: 0.9588 - recall: 0.8726 - val_loss: 0.0045 - val_accuracy: 0.9995 - val_precision: 0.9487 - val_recall: 0.7957
#
# Epoch 00039: val_loss did not improve from 0.00375
# Epoch 40/100
# 1937/1937 [==============================] - 1s 729us/step - loss: 0.0014 - accuracy: 0.9997 - precision: 0.9688 - recall: 0.8677 - val_loss: 0.0054 - val_accuracy: 0.9994 - val_precision: 0.9559 - val_recall: 0.6989
#
# Epoch 00040: val_loss did not improve from 0.00375
# Epoch 41/100
# 1937/1937 [==============================] - 1s 719us/step - loss: 0.0013 - accuracy: 0.9997 - precision: 0.9534 - recall: 0.8397 - val_loss: 0.0049 - val_accuracy: 0.9996 - val_precision: 0.9615 - val_recall: 0.8065
#
# Epoch 00041: val_loss did not improve from 0.00375

# %% [markdown]
# ### 모델의 테스트 데이터에 대한 정확도, 정밀도, 재현율

# %%
print(model.evaluate(X_test, Y_test))
#학습한 모델로 테스트 정확도 측정
# Out:
# 1336/1336 [==============================] - 1s 448us/step - loss: 0.0050 - accuracy: 0.9995 - precision: 0.8667 - recall: 0.7761
# [0.005023868754506111, 0.9994616508483887, 0.8666666746139526, 0.7761194109916687]

# %% [markdown]
# ### 모델의 전체 데이터에 대한 정밀도, 재현율

# %%
predict = model.predict(X)    #predict만 사용한 후 for문을 사용해 직접 Y의 답과 비교
#예측에 X_test 말고 X를 사용한 이유는 사기인 경우가 너무 적어서 X_test에 거의 안들어 갈 수 있다 생각했기 때문

# %%
for i in range(10):
    print('%.10f' % predict[i], Y[i])
# Out:
# 0.0028277636 0.0
# 0.0000000002 0.0
# 0.0002302527 0.0
# 0.0000000257 0.0
# 0.0000044126 0.0
# 0.0000000024 0.0
# 0.0000000029 0.0
# 0.0000000235 0.0
# 0.0000000008 0.0
# 0.0000000000 0.0

# %% [markdown]
# #### 임의로 predict값이 0.5 보다 높으면 1로 아니면 0으로 예측한 것이라 판단하여 정밀도, 재현율을 측정

# %%
tp = 0
fp = 0
tn = 0
fn = 0
for index, i in enumerate(Y):
    if i == 1.0:
        if (predict[index] > 0.5):
            tp += 1
        else :
            fn += 1
    else:
        if (predict[index] > 0.5):
            fp += 1
        else :
            tn += 1
print(tp, fp, tn, fn)
# Out:
# 422 19 284296 70

# %%
print("precision =\t", tp / (tp + fp))
print("recall =\t", tp / (tp + fn))
# Out:
# precision =	 0.9569160997732427
# recall =	 0.8577235772357723

# %% [markdown]
# ### 정확도와 val_loss 시각화

# %%
y_vloss = history.history['val_loss']
y_acc = history.history['accuracy']
x_len = numpy.arange(len(y_vloss))
plt.plot(x_len, y_vloss, 'o', c='red', markersize=3)
plt.plot(x_len, y_acc, 'o', c='blue', markersize=3)
plt.show()    #epoch를 100번만 줘서 별로 많이 나타나지는 않고 그마저도 거의 100%에 가까운 정확도를 보임

# %% [markdown]
# ## 2. 데이터 중 Amount를 정규화 한 경우

# %%
scaler= MinMaxScaler()    #정규화를 위해 MinMaxScaler를 호출
df['Amount'] = scaler.fit_transform(df['Amount'].values.reshape(-1,1))    #이 메소드로 정규화 실행, reshape의 파라미터는 무슨 역할인지 까먹음

# %%
df    #Amount가 정규화 된 것을 확인
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 0       0.462388  0.239599  0.098698  0.363787  ... -0.018307  0.277838
# 1      -0.082361 -0.078803  0.085102 -0.255425  ... -0.225775 -0.638672
# 2       1.800499  0.791461  0.247676 -1.514654  ...  0.247998  0.771679
# 3       1.247203  0.237609  0.377436 -1.387024  ... -0.108300  0.005274
# 4       0.095921  0.592941 -0.270533  0.817739  ... -0.009431  0.798278
# ...          ...       ...       ...       ...  ...       ...       ...
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28    Amount  \
# 0      -0.110474  0.066928  0.128539 -0.189115  0.133558 -0.021053  0.005824
# 1       0.101288 -0.339846  0.167170  0.125895 -0.008983  0.014724  0.000105
# 2       0.909412 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752  0.014739
# 3      -0.190321 -1.175575  0.647376 -0.221929  0.062723  0.061458  0.004807
# 4      -0.137458  0.141267 -0.206010  0.502292  0.219422  0.215153  0.002724
# ...          ...       ...       ...       ...       ...       ...       ...
# 284802  1.014480 -0.509348  1.436807  0.250034  0.943651  0.823731  0.000030
# 284803  0.012463 -1.016226 -0.606624 -0.395255  0.068472 -0.053527  0.000965
# 284804 -0.037501  0.640134  0.265745 -0.087371  0.004455 -0.026561  0.002642
# 284805 -0.163298  0.123205 -0.569159  0.546668  0.108821  0.104533  0.000389
# 284806  0.376777  0.008797 -0.473649 -0.818267 -0.002415  0.013649  0.008446
#
#         Class
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 284802      0
# 284803      0
# 284804      0
# 284805      0
# 284806      0
#
# [284807 rows x 31 columns]

# %%
plt.figure(figsize = (14,14))
plt.title('Credit Card Transactions features correlation plot (Pearson)')
corr = df.corr()
sns.heatmap(corr,xticklabels=corr.columns,yticklabels=corr.columns,linewidths=.1,cmap="Reds")
plt.show()

# %%
#CSV 데이터 종속, 독립 변수 분할
dataset = df.values
X = dataset[:,1:30]

Y = dataset[:,30]       #종속변수
#훈련, 테스트 데이터 분할
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.15, random_state=3)

# %%
#모델 컴파일 및 학습
model.compile(loss='binary_crossentropy',
             optimizer='adam',
             metrics=['accuracy',tf.keras.metrics.Precision(name='precision'),tf.keras.metrics.Recall(name='recall')])
MODEL_DIR = './credit_model/'

if not os.path.exists(MODEL_DIR):
    os.mkdir(MODEL_DIR)
    
modelpath = './model/{epoch:02d}-{val_loss:.4f}.hdf5'
checkpointer = ModelCheckpoint(filepath = modelpath, monitor = 'val_loss', verbose = 1, save_best_only=True)

early_stopping_callback= EarlyStopping(monitor= 'val_loss', patience = 20)

history = model.fit(X_train, Y_train, validation_split=0.2, epochs=100, batch_size=100, callbacks = [early_stopping_callback,checkpointer])
# Out:
# Epoch 1/100
# 1937/1937 [==============================] - 2s 867us/step - loss: 0.0033 - accuracy: 0.9995 - precision: 0.9124 - recall: 0.8154 - val_loss: 0.0038 - val_accuracy: 0.9994 - val_precision: 0.9333 - val_recall: 0.7527
#
# Epoch 00001: val_loss improved from inf to 0.00383, saving model to ./model\01-0.0038.hdf5
# Epoch 2/100
# 1937/1937 [==============================] - 1s 720us/step - loss: 0.0016 - accuracy: 0.9997 - precision: 0.9377 - recall: 0.8538 - val_loss: 0.0039 - val_accuracy: 0.9993 - val_precision: 0.8861 - val_recall: 0.7527
#
# Epoch 00002: val_loss did not improve from 0.00383
# Epoch 3/100
# 1937/1937 [==============================] - 1s 718us/step - loss: 0.0017 - accuracy: 0.9996 - precision: 0.9280 - recall: 0.7918 - val_loss: 0.0040 - val_accuracy: 0.9994 - val_precision: 0.8721 - val_recall: 0.8065
#
# Epoch 00003: val_loss did not improve from 0.00383
# Epoch 4/100
# 1937/1937 [==============================] - 1s 719us/step - loss: 0.0012 - accuracy: 0.9997 - precision: 0.9651 - recall: 0.8657 - val_loss: 0.0043 - val_accuracy: 0.9994 - val_precision: 0.9200 - val_recall: 0.7419
#
# Epoch 00004: val_loss did not improve from 0.00383
# Epoch 5/100
# 1937/1937 [==============================] - 1s 714us/step - loss: 0.0012 - accuracy: 0.9997 - precision: 0.9515 - recall: 0.8760 - val_loss: 0.0040 - val_accuracy: 0.9994 - val_precision: 0.9012 - val_recall: 0.7849
#
# Epoch 00005: val_loss did not improve from 0.00383
# Epoch 6/100
# 1937/1937 [==============================] - 1s 717us/step - loss: 0.0011 - accuracy: 0.9997 - precision: 0.9612 - recall: 0.8802 - val_loss: 0.0051 - val_accuracy: 0.9993 - val_precision: 0.8933 - val_recall: 0.7204
#
# Epoch 00006: val_loss did not improve from 0.00383
# Epoch 7/100
# 1937/1937 [==============================] - 1s 716us/step - loss: 0.0013 - accuracy: 0.9997 - precision: 0.9566 - recall: 0.8478 - val_loss: 0.0051 - val_accuracy: 0.9993 - val_precision: 0.9041 - val_recall: 0.7097
#
# Epoch 00007: val_loss did not improve from 0.00383
# Epoch 8/100
# 1937/1937 [==============================] - 1s 715us/step - loss: 0.0013 - accuracy: 0.9997 - precision: 0.9717 - recall: 0.8797 - val_loss: 0.0051 - val_accuracy: 0.9993 - val_precision: 0.8947 - val_recall: 0.7312
#
# Epoch 00008: val_loss did not improve from 0.00383
# Epoch 9/100
# 1937/1937 [==============================] - 1s 720us/step - loss: 8.1933e-04 - accuracy: 0.9998 - precision: 0.9735 - recall: 0.8830 - val_loss: 0.0063 - val_accuracy: 0.9993 - val_precision: 0.9028 - val_recall: 0.6989
#
# Epoch 00009: val_loss did not improve from 0.00383
# Epoch 10/100
# 1937/1937 [==============================] - 1s 716us/step - loss: 8.8414e-04 - accuracy: 0.9998 - precision: 0.9552 - recall: 0.8983 - val_loss: 0.0055 - val_accuracy: 0.9993 - val_precision: 0.8961 - val_recall: 0.7419
#
# Epoch 00010: val_loss did not improve from 0.00383
# Epoch 11/100
# 1937/1937 [==============================] - 1s 722us/step - loss: 7.9695e-04 - accuracy: 0.9998 - precision: 0.9770 - recall: 0.8906 - val_loss: 0.0053 - val_accuracy: 0.9994 - val_precision: 0.9306 - val_recall: 0.7204
#
# Epoch 00011: val_loss did not improve from 0.00383
# Epoch 12/100
# 1937/1937 [==============================] - 1s 718us/step - loss: 7.6488e-04 - accuracy: 0.9998 - precision: 0.9759 - recall: 0.8778 - val_loss: 0.0055 - val_accuracy: 0.9993 - val_precision: 0.8961 - val_recall: 0.7419
#
# Epoch 00012: val_loss did not improve from 0.00383
# Epoch 13/100
# 1937/1937 [==============================] - 1s 722us/step - loss: 8.6404e-04 - accuracy: 0.9998 - precision: 0.9764 - recall: 0.8958 - val_loss: 0.0059 - val_accuracy: 0.9993 - val_precision: 0.8765 - val_recall: 0.7634
#
# Epoch 00013: val_loss did not improve from 0.00383
# Epoch 14/100
# 1937/1937 [==============================] - 1s 717us/step - loss: 9.8874e-04 - accuracy: 0.9998 - precision: 0.9820 - recall: 0.8578 - val_loss: 0.0074 - val_accuracy: 0.9992 - val_precision: 0.8889 - val_recall: 0.6882
#
# Epoch 00014: val_loss did not improve from 0.00383
# Epoch 15/100
# 1937/1937 [==============================] - 1s 717us/step - loss: 0.0010 - accuracy: 0.9997 - precision: 0.9548 - recall: 0.8807 - val_loss: 0.0072 - val_accuracy: 0.9992 - val_precision: 0.9242 - val_recall: 0.6559
#
# Epoch 00015: val_loss did not improve from 0.00383
# Epoch 16/100
# 1937/1937 [==============================] - 1s 731us/step - loss: 9.3093e-04 - accuracy: 0.9998 - precision: 0.9612 - recall: 0.8794 - val_loss: 0.0080 - val_accuracy: 0.9992 - val_precision: 0.8986 - val_recall: 0.6667
#
# Epoch 00016: val_loss did not improve from 0.00383
# Epoch 17/100
# 1937/1937 [==============================] - 1s 713us/step - loss: 9.5152e-04 - accuracy: 0.9998 - precision: 0.9664 - recall: 0.8940 - val_loss: 0.0070 - val_accuracy: 0.9994 - val_precision: 0.8875 - val_recall: 0.7634
#
# Epoch 00017: val_loss did not improve from 0.00383
# Epoch 18/100
# 1937/1937 [==============================] - 1s 712us/step - loss: 8.8781e-04 - accuracy: 0.9998 - precision: 0.9711 - recall: 0.8900 - val_loss: 0.0075 - val_accuracy: 0.9993 - val_precision: 0.8861 - val_recall: 0.7527
#
# Epoch 00018: val_loss did not improve from 0.00383
# Epoch 19/100
# 1937/1937 [==============================] - 1s 716us/step - loss: 7.8152e-04 - accuracy: 0.9998 - precision: 0.9883 - recall: 0.9158 - val_loss: 0.0077 - val_accuracy: 0.9993 - val_precision: 0.9014 - val_recall: 0.6882
#
# Epoch 00019: val_loss did not improve from 0.00383
# Epoch 20/100
# 1937/1937 [==============================] - 1s 738us/step - loss: 7.7683e-04 - accuracy: 0.9998 - precision: 0.9851 - recall: 0.8888 - val_loss: 0.0081 - val_accuracy: 0.9993 - val_precision: 0.8904 - val_recall: 0.6989
#
# Epoch 00020: val_loss did not improve from 0.00383
# Epoch 21/100
# 1937/1937 [==============================] - 1s 719us/step - loss: 6.0038e-04 - accuracy: 0.9998 - precision: 0.9788 - recall: 0.9289 - val_loss: 0.0080 - val_accuracy: 0.9993 - val_precision: 0.8933 - val_recall: 0.7204
#
# Epoch 00021: val_loss did not improve from 0.00383

# %% [markdown]
# ### 모델의 테스트 데이터에 대한 정확도, 정밀도, 재현율

# %%
print(model.evaluate(X_test, Y_test))
# Out:
# 1336/1336 [==============================] - 1s 459us/step - loss: 0.0056 - accuracy: 0.9994 - precision: 0.8448 - recall: 0.7313
# [0.005629068706184626, 0.9993680119514465, 0.8448275923728943, 0.7313432693481445]

# %% [markdown]
# ### 모델의 전체 데이터에 대한 정밀도, 재현율

# %%
predict = model.predict(X)

# %%
for i in range(10):
    print('%.10f' % predict[i], Y[i])
# Out:
# 0.0000022488 0.0
# 0.0000000006 0.0
# 0.0000000000 0.0
# 0.0000000858 0.0
# 0.0000000050 0.0
# 0.0000002177 0.0
# 0.0000016185 0.0
# 0.0000000000 0.0
# 0.0000005250 0.0
# 0.0000000253 0.0

# %%
tp = 0
fp = 0
tn = 0
fn = 0
for index, i in enumerate(Y):
    if i == 1.0:
        if (predict[index] > 0.5):
            tp += 1
        else :
            fn += 1
    else:
        if (predict[index] > 0.5):
            fp += 1
        else :
            tn += 1
print(tp, fp, tn, fn)
# Out:
# 429 24 284291 63

# %%
print("precision =\t", tp / (tp + fp))
print("recall =\t", tp / (tp + fn))
# Out:
# precision =	 0.9470198675496688
# recall =	 0.8719512195121951

# %%
y_vloss = history.history['val_loss']
y_acc = history.history['accuracy']
x_len = numpy.arange(len(y_vloss))
plt.plot(x_len, y_vloss, 'o', c='red', markersize=3)
plt.plot(x_len, y_acc, 'o', c='blue', markersize=3)
plt.show()

# %% [markdown]
# ## 3. 데이터 정규화 후 셔플로 데이터를 섞음

# %%
df = df.sample(frac = 1)    #섞을 때 사용하는 메소드

# %%
df    #섞인거 확인
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 183484  125821.0 -0.323334  1.057455 -0.048341 -0.607204  1.259821 -0.091761
# 255448  157235.0 -0.349718  0.932619  0.142992 -0.657071  1.169784 -0.733369
# 244749  152471.0 -1.614711 -2.406570  0.326194  0.665520  2.369268 -1.775367
# 63919    50927.0 -2.477184  0.860613  1.441850  1.051019 -1.856621  2.078384
# 11475    19899.0  1.338831 -0.547264  0.737389 -0.212383 -1.110039 -0.525744
# ...          ...       ...       ...       ...       ...       ...       ...
# 211543  138459.0 -1.321976  1.138686 -0.940861  0.154160  0.109802 -0.538822
# 86293    61167.0 -0.627810  0.918729  1.478453  0.213171  0.933695  1.261486
# 122579   76616.0  1.512602 -0.949435 -0.219062 -1.638850 -0.856348 -0.465996
# 152315   97253.0  1.798863 -1.699791 -0.142182 -0.619533 -1.570248  0.083268
# 117952   74887.0 -0.589400  0.747828  1.784781  0.899612  0.257067 -0.001301
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 183484  1.159101 -0.124335 -0.174640  ... -0.207098 -0.433890 -0.261613
# 255448  1.009985 -0.071069 -0.302083  ... -0.271537 -0.833209 -0.030360
# 244749 -1.139049  0.329904  0.903813  ...  0.701399  1.134489  0.965054
# 63919   0.510828 -0.243399 -0.260691  ...  0.810408  0.692245  0.150121
# 11475  -0.801403 -0.063672  0.997276  ... -0.139436 -0.074719  0.067055
# ...          ...       ...       ...  ...       ...       ...       ...
# 211543  0.490058  0.513762 -0.493834  ... -0.012778 -0.237503  0.008713
# 86293   0.504752  0.404286 -0.939740  ... -0.051356 -0.004245  0.090535
# 122579 -0.669193 -0.135566 -2.284345  ... -0.558803 -1.377240  0.080444
# 152315 -1.501980  0.176287  1.755507  ...  0.181914  0.351358  0.115638
# 117952  0.122334  0.034736 -0.283998  ... -0.008910  0.000367 -0.238139
#
#              V24       V25       V26       V27       V28    Amount  Class
# 183484 -0.046651  0.211512  0.008297  0.108494  0.161139  0.001557      0
# 255448  0.490035 -0.404816  0.134350  0.076830  0.175562  0.000077      0
# 244749  0.640981 -1.801998 -1.041114  0.286285  0.437322  0.003737      0
# 63919  -0.260777  0.005183 -0.177847 -0.510060 -0.660533  0.011989      0
# 11475   0.333122  0.379087 -0.268706 -0.002769  0.003272  0.000195      0
# ...          ...       ...       ...       ...       ...       ...    ...
# 211543 -0.767844 -0.397162  0.316379 -0.463125 -0.010589  0.001942      0
# 86293  -0.964599 -0.522294  0.296733  0.145939  0.110400  0.000973      0
# 122579 -0.579511  0.297851 -0.495367 -0.001415  0.003665  0.001358      0
# 152315 -0.566188 -0.596200 -0.295152 -0.033616 -0.032471  0.006668      0
# 117952 -0.463529 -0.243573 -0.370920  0.086592  0.118084  0.000622      0
#
# [284807 rows x 31 columns]

# %%
#CSV 데이터 종속, 독립 변수 분할
dataset = df.values
X = dataset[:,1:30]

Y = dataset[:,30]       #종속변수
#훈련, 테스트 데이터 분할
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.15, random_state=3)

# %%
#모델 컴파일 및 학습
model.compile(loss='binary_crossentropy',
             optimizer='adam',
             metrics=['accuracy',tf.keras.metrics.Precision(name='precision'),tf.keras.metrics.Recall(name='recall')])
MODEL_DIR = './credit_model/'

if not os.path.exists(MODEL_DIR):
    os.mkdir(MODEL_DIR)
    
modelpath = './model/{epoch:02d}-{val_loss:.4f}.hdf5'
checkpointer = ModelCheckpoint(filepath = modelpath, monitor = 'val_loss', verbose = 1, save_best_only=True)

early_stopping_callback= EarlyStopping(monitor= 'val_loss', patience = 20)

history = model.fit(X_train, Y_train, validation_split=0.2, epochs=100, batch_size=100, callbacks = [early_stopping_callback,checkpointer])
# Out:
# Epoch 1/100
# 1937/1937 [==============================] - 2s 843us/step - loss: 0.0021 - accuracy: 0.9997 - precision: 0.9465 - recall: 0.8554 - val_loss: 0.0034 - val_accuracy: 0.9996 - val_precision: 0.9753 - val_recall: 0.8061
#
# Epoch 00001: val_loss improved from inf to 0.00340, saving model to ./model\01-0.0034.hdf5
# Epoch 2/100
# 1937/1937 [==============================] - 1s 711us/step - loss: 0.0013 - accuracy: 0.9997 - precision: 0.9728 - recall: 0.8663 - val_loss: 0.0034 - val_accuracy: 0.9995 - val_precision: 0.9390 - val_recall: 0.7857
#
# Epoch 00002: val_loss improved from 0.00340 to 0.00339, saving model to ./model\02-0.0034.hdf5
# Epoch 3/100
# 1937/1937 [==============================] - 1s 700us/step - loss: 0.0015 - accuracy: 0.9997 - precision: 0.9519 - recall: 0.8683 - val_loss: 0.0036 - val_accuracy: 0.9995 - val_precision: 0.9506 - val_recall: 0.7857
#
# Epoch 00003: val_loss did not improve from 0.00339
# Epoch 4/100
# 1937/1937 [==============================] - 1s 709us/step - loss: 0.0014 - accuracy: 0.9997 - precision: 0.9579 - recall: 0.8637 - val_loss: 0.0035 - val_accuracy: 0.9994 - val_precision: 0.9733 - val_recall: 0.7449
#
# Epoch 00004: val_loss did not improve from 0.00339
# Epoch 5/100
# 1937/1937 [==============================] - 1s 713us/step - loss: 0.0013 - accuracy: 0.9997 - precision: 0.9724 - recall: 0.8584 - val_loss: 0.0036 - val_accuracy: 0.9994 - val_precision: 0.8941 - val_recall: 0.7755
#
# Epoch 00005: val_loss did not improve from 0.00339
# Epoch 6/100
# 1937/1937 [==============================] - 1s 702us/step - loss: 0.0013 - accuracy: 0.9997 - precision: 0.9593 - recall: 0.8822 - val_loss: 0.0037 - val_accuracy: 0.9995 - val_precision: 0.9294 - val_recall: 0.8061
#
# Epoch 00006: val_loss did not improve from 0.00339
# Epoch 7/100
# 1937/1937 [==============================] - 1s 703us/step - loss: 0.0017 - accuracy: 0.9996 - precision: 0.9281 - recall: 0.8388 - val_loss: 0.0040 - val_accuracy: 0.9994 - val_precision: 0.9136 - val_recall: 0.7551
#
# Epoch 00007: val_loss did not improve from 0.00339
# Epoch 8/100
# 1937/1937 [==============================] - 1s 703us/step - loss: 0.0011 - accuracy: 0.9998 - precision: 0.9756 - recall: 0.8926 - val_loss: 0.0039 - val_accuracy: 0.9995 - val_precision: 0.9868 - val_recall: 0.7653
#
# Epoch 00008: val_loss did not improve from 0.00339
# Epoch 9/100
# 1937/1937 [==============================] - 1s 701us/step - loss: 0.0010 - accuracy: 0.9997 - precision: 0.9608 - recall: 0.8759 - val_loss: 0.0043 - val_accuracy: 0.9993 - val_precision: 0.9851 - val_recall: 0.6735
#
# Epoch 00009: val_loss did not improve from 0.00339
# Epoch 10/100
# 1937/1937 [==============================] - 1s 709us/step - loss: 0.0011 - accuracy: 0.9997 - precision: 0.9578 - recall: 0.8828 - val_loss: 0.0048 - val_accuracy: 0.9995 - val_precision: 0.9865 - val_recall: 0.7449
#
# Epoch 00010: val_loss did not improve from 0.00339
# Epoch 11/100
# 1937/1937 [==============================] - 1s 703us/step - loss: 8.6027e-04 - accuracy: 0.9998 - precision: 0.9754 - recall: 0.8696 - val_loss: 0.0045 - val_accuracy: 0.9994 - val_precision: 0.9367 - val_recall: 0.7551
#
# Epoch 00011: val_loss did not improve from 0.00339
# Epoch 12/100
# 1937/1937 [==============================] - 1s 700us/step - loss: 8.8426e-04 - accuracy: 0.9998 - precision: 0.9730 - recall: 0.9087 - val_loss: 0.0048 - val_accuracy: 0.9994 - val_precision: 0.9730 - val_recall: 0.7347
#
# Epoch 00012: val_loss did not improve from 0.00339
# Epoch 13/100
# 1937/1937 [==============================] - 1s 703us/step - loss: 0.0010 - accuracy: 0.9998 - precision: 0.9666 - recall: 0.8916 - val_loss: 0.0051 - val_accuracy: 0.9992 - val_precision: 0.8765 - val_recall: 0.7245
#
# Epoch 00013: val_loss did not improve from 0.00339
# Epoch 14/100
# 1937/1937 [==============================] - 1s 697us/step - loss: 9.9337e-04 - accuracy: 0.9998 - precision: 0.9800 - recall: 0.8763 - val_loss: 0.0053 - val_accuracy: 0.9994 - val_precision: 0.9351 - val_recall: 0.7347
#
# Epoch 00014: val_loss did not improve from 0.00339
# Epoch 15/100
# 1937/1937 [==============================] - 1s 702us/step - loss: 7.8401e-04 - accuracy: 0.9998 - precision: 0.9551 - recall: 0.9192 - val_loss: 0.0059 - val_accuracy: 0.9992 - val_precision: 0.8831 - val_recall: 0.6939
#
# Epoch 00015: val_loss did not improve from 0.00339
# Epoch 16/100
# 1937/1937 [==============================] - 1s 705us/step - loss: 6.9220e-04 - accuracy: 0.9998 - precision: 0.9953 - recall: 0.9084 - val_loss: 0.0058 - val_accuracy: 0.9992 - val_precision: 0.9178 - val_recall: 0.6837
#
# Epoch 00016: val_loss did not improve from 0.00339
# Epoch 17/100
# 1937/1937 [==============================] - 1s 700us/step - loss: 7.3119e-04 - accuracy: 0.9998 - precision: 0.9912 - recall: 0.8901 - val_loss: 0.0058 - val_accuracy: 0.9994 - val_precision: 0.9351 - val_recall: 0.7347
#
# Epoch 00017: val_loss did not improve from 0.00339
# Epoch 18/100
# 1937/1937 [==============================] - 1s 701us/step - loss: 7.8369e-04 - accuracy: 0.9998 - precision: 0.9605 - recall: 0.8896 - val_loss: 0.0062 - val_accuracy: 0.9993 - val_precision: 0.8605 - val_recall: 0.7551
#
# Epoch 00018: val_loss did not improve from 0.00339
# Epoch 19/100
# 1937/1937 [==============================] - 1s 697us/step - loss: 8.1098e-04 - accuracy: 0.9998 - precision: 0.9647 - recall: 0.8989 - val_loss: 0.0072 - val_accuracy: 0.9992 - val_precision: 0.8734 - val_recall: 0.7041
#
# Epoch 00019: val_loss did not improve from 0.00339
# Epoch 20/100
# 1937/1937 [==============================] - 1s 700us/step - loss: 7.2705e-04 - accuracy: 0.9998 - precision: 0.9493 - recall: 0.9276 - val_loss: 0.0069 - val_accuracy: 0.9992 - val_precision: 0.8861 - val_recall: 0.7143
#
# Epoch 00020: val_loss did not improve from 0.00339
# Epoch 21/100
# 1937/1937 [==============================] - 1s 707us/step - loss: 7.7547e-04 - accuracy: 0.9997 - precision: 0.9575 - recall: 0.8539 - val_loss: 0.0073 - val_accuracy: 0.9992 - val_precision: 0.9296 - val_recall: 0.6735
#
# Epoch 00021: val_loss did not improve from 0.00339
# Epoch 22/100
# 1937/1937 [==============================] - 1s 695us/step - loss: 7.9559e-04 - accuracy: 0.9997 - precision: 0.9757 - recall: 0.8490 - val_loss: 0.0083 - val_accuracy: 0.9990 - val_precision: 0.8551 - val_recall: 0.6020
#
# Epoch 00022: val_loss did not improve from 0.00339

# %% [markdown]
# ### 모델의 테스트 데이터에 대한 정확도, 정밀도, 재현율

# %%
print(model.evaluate(X_test, Y_test))
# Out:
# 1336/1336 [==============================] - 1s 462us/step - loss: 0.0028 - accuracy: 0.9993 - precision: 0.8704 - recall: 0.6812
# [0.002808609511703253, 0.9993212223052979, 0.8703703880310059, 0.6811594367027283]

# %% [markdown]
# ### 모델의 전체 데이터에 대한 정밀도, 재현율

# %%
predict = model.predict(X)

# %%
for i in range(10):
    print('%.10f' % predict[i], Y[i])
# Out:
# 0.0001775324 0.0
# 0.0000003636 0.0
# 0.0000000000 0.0
# 0.0000000172 0.0
# 0.0000000049 0.0
# 0.0001112687 0.0
# 0.0000010462 0.0
# 0.0000000000 0.0
# 0.0000000001 0.0
# 0.0003398061 0.0

# %%
tp = 0
fp = 0
tn = 0
fn = 0
for index, i in enumerate(Y):
    if i == 1.0:
        if (predict[index] > 0.5):
            tp += 1
        else :
            fn += 1
    else:
        if (predict[index] > 0.5):
            fp += 1
        else :
            tn += 1
print(tp, fp, tn, fn)
# Out:
# 363 21 284294 129

# %%
print("precision =\t", tp / (tp + fp))
print("recall =\t", tp / (tp + fn))
# Out:
# precision =	 0.9453125
# recall =	 0.7378048780487805

# %%
y_vloss = history.history['val_loss']
y_acc = history.history['accuracy']
x_len = numpy.arange(len(y_vloss))
plt.plot(x_len, y_vloss, 'o', c='red', markersize=3)
plt.plot(x_len, y_acc, 'o', c='blue', markersize=3)
plt.show()

# %% [markdown]
# ## 4. ANN 모델 사용

# %%
#모델 구조 생성 Dense 값들은 그냥 아무렇게나 준 것
model = Sequential()
model.add(Dense(15,  input_dim=29, activation='relu'))    #학습에 사용될 데이터의 열이 29개 이므로 input_dim을 29로 줌
model.add(Dense(1, activation='sigmoid'))    #최종 결과가 0아니면 1인 이진 분류이므로 sigmoid 사용

# %%
#모델 컴파일 및 학습
model.compile(loss='binary_crossentropy',
             optimizer='adam',
             metrics=['accuracy',tf.keras.metrics.Precision(name='precision'),tf.keras.metrics.Recall(name='recall')])
MODEL_DIR = './credit_model/'

if not os.path.exists(MODEL_DIR):
    os.mkdir(MODEL_DIR)
    
modelpath = './model/{epoch:02d}-{val_loss:.4f}.hdf5'
checkpointer = ModelCheckpoint(filepath = modelpath, monitor = 'val_loss', verbose = 1, save_best_only=True)

early_stopping_callback= EarlyStopping(monitor= 'val_loss', patience = 20)

history = model.fit(X_train, Y_train, validation_split=0.2, epochs=100, batch_size=100, callbacks = [early_stopping_callback,checkpointer])
# Out:
# Epoch 1/100
# 1937/1937 [==============================] - 2s 802us/step - loss: 0.2496 - accuracy: 0.8825 - precision: 0.0125 - recall: 0.3433 - val_loss: 0.0093 - val_accuracy: 0.9987 - val_precision: 0.7797 - val_recall: 0.4694
#
# Epoch 00001: val_loss improved from inf to 0.00933, saving model to ./model\01-0.0093.hdf5
# Epoch 2/100
# 1937/1937 [==============================] - 1s 668us/step - loss: 0.0054 - accuracy: 0.9993 - precision: 0.8761 - recall: 0.6801 - val_loss: 0.0064 - val_accuracy: 0.9990 - val_precision: 0.8429 - val_recall: 0.6020
#
# Epoch 00002: val_loss improved from 0.00933 to 0.00640, saving model to ./model\02-0.0064.hdf5
# Epoch 3/100
# 1937/1937 [==============================] - 1s 658us/step - loss: 0.0035 - accuracy: 0.9994 - precision: 0.8905 - recall: 0.7240 - val_loss: 0.0057 - val_accuracy: 0.9989 - val_precision: 0.8382 - val_recall: 0.5816
#
# Epoch 00003: val_loss improved from 0.00640 to 0.00574, saving model to ./model\03-0.0057.hdf5
# Epoch 4/100
# 1937/1937 [==============================] - 1s 661us/step - loss: 0.0027 - accuracy: 0.9995 - precision: 0.9199 - recall: 0.7694 - val_loss: 0.0060 - val_accuracy: 0.9991 - val_precision: 0.8313 - val_recall: 0.7041
#
# Epoch 00004: val_loss did not improve from 0.00574
# Epoch 5/100
# 1937/1937 [==============================] - 1s 653us/step - loss: 0.0030 - accuracy: 0.9995 - precision: 0.9207 - recall: 0.7870 - val_loss: 0.0054 - val_accuracy: 0.9990 - val_precision: 0.8049 - val_recall: 0.6735
#
# Epoch 00005: val_loss improved from 0.00574 to 0.00542, saving model to ./model\05-0.0054.hdf5
# Epoch 6/100
# 1937/1937 [==============================] - 1s 671us/step - loss: 0.0031 - accuracy: 0.9994 - precision: 0.9079 - recall: 0.7710 - val_loss: 0.0053 - val_accuracy: 0.9991 - val_precision: 0.8873 - val_recall: 0.6429
#
# Epoch 00006: val_loss improved from 0.00542 to 0.00526, saving model to ./model\06-0.0053.hdf5
# Epoch 7/100
# 1937/1937 [==============================] - 1s 656us/step - loss: 0.0032 - accuracy: 0.9994 - precision: 0.8950 - recall: 0.7357 - val_loss: 0.0052 - val_accuracy: 0.9991 - val_precision: 0.8873 - val_recall: 0.6429
#
# Epoch 00007: val_loss improved from 0.00526 to 0.00515, saving model to ./model\07-0.0052.hdf5
# Epoch 8/100
# 1937/1937 [==============================] - 1s 658us/step - loss: 0.0025 - accuracy: 0.9995 - precision: 0.9239 - recall: 0.7855 - val_loss: 0.0050 - val_accuracy: 0.9991 - val_precision: 0.8767 - val_recall: 0.6531
#
# Epoch 00008: val_loss improved from 0.00515 to 0.00498, saving model to ./model\08-0.0050.hdf5
# Epoch 9/100
# 1937/1937 [==============================] - 1s 655us/step - loss: 0.0025 - accuracy: 0.9994 - precision: 0.8999 - recall: 0.7566 - val_loss: 0.0051 - val_accuracy: 0.9992 - val_precision: 0.9130 - val_recall: 0.6429
#
# Epoch 00009: val_loss did not improve from 0.00498
# Epoch 10/100
# 1937/1937 [==============================] - 1s 661us/step - loss: 0.0023 - accuracy: 0.9996 - precision: 0.9337 - recall: 0.8092 - val_loss: 0.0050 - val_accuracy: 0.9991 - val_precision: 0.8272 - val_recall: 0.6837
#
# Epoch 00010: val_loss did not improve from 0.00498
# Epoch 11/100
# 1937/1937 [==============================] - 1s 658us/step - loss: 0.0022 - accuracy: 0.9995 - precision: 0.9101 - recall: 0.7768 - val_loss: 0.0050 - val_accuracy: 0.9991 - val_precision: 0.8333 - val_recall: 0.7143
#
# Epoch 00011: val_loss improved from 0.00498 to 0.00496, saving model to ./model\11-0.0050.hdf5
# Epoch 12/100
# 1937/1937 [==============================] - 1s 654us/step - loss: 0.0024 - accuracy: 0.9995 - precision: 0.8987 - recall: 0.7753 - val_loss: 0.0055 - val_accuracy: 0.9990 - val_precision: 0.8421 - val_recall: 0.6531
#
# Epoch 00012: val_loss did not improve from 0.00496
# Epoch 13/100
# 1937/1937 [==============================] - 1s 661us/step - loss: 0.0027 - accuracy: 0.9995 - precision: 0.9073 - recall: 0.7844 - val_loss: 0.0054 - val_accuracy: 0.9991 - val_precision: 0.8732 - val_recall: 0.6327
#
# Epoch 00013: val_loss did not improve from 0.00496
# Epoch 14/100
# 1937/1937 [==============================] - 1s 656us/step - loss: 0.0023 - accuracy: 0.9995 - precision: 0.8851 - recall: 0.7436 - val_loss: 0.0050 - val_accuracy: 0.9990 - val_precision: 0.8378 - val_recall: 0.6327
#
# Epoch 00014: val_loss did not improve from 0.00496
# Epoch 15/100
# 1937/1937 [==============================] - 1s 654us/step - loss: 0.0023 - accuracy: 0.9995 - precision: 0.9085 - recall: 0.8107 - val_loss: 0.0051 - val_accuracy: 0.9991 - val_precision: 0.9365 - val_recall: 0.6020
#
# Epoch 00015: val_loss did not improve from 0.00496
# Epoch 16/100
# 1937/1937 [==============================] - 1s 654us/step - loss: 0.0019 - accuracy: 0.9997 - precision: 0.9488 - recall: 0.8225 - val_loss: 0.0049 - val_accuracy: 0.9992 - val_precision: 0.8642 - val_recall: 0.7143
#
# Epoch 00016: val_loss improved from 0.00496 to 0.00486, saving model to ./model\16-0.0049.hdf5
# Epoch 17/100
# 1937/1937 [==============================] - 1s 656us/step - loss: 0.0021 - accuracy: 0.9995 - precision: 0.9271 - recall: 0.7929 - val_loss: 0.0049 - val_accuracy: 0.9991 - val_precision: 0.8857 - val_recall: 0.6327
#
# Epoch 00017: val_loss improved from 0.00486 to 0.00486, saving model to ./model\17-0.0049.hdf5
# Epoch 18/100
# 1937/1937 [==============================] - 1s 661us/step - loss: 0.0022 - accuracy: 0.9996 - precision: 0.9394 - recall: 0.7994 - val_loss: 0.0051 - val_accuracy: 0.9991 - val_precision: 0.8500 - val_recall: 0.6939
#
# Epoch 00018: val_loss did not improve from 0.00486
# Epoch 19/100
# 1937/1937 [==============================] - 1s 656us/step - loss: 0.0018 - accuracy: 0.9997 - precision: 0.9477 - recall: 0.8339 - val_loss: 0.0053 - val_accuracy: 0.9991 - val_precision: 0.8293 - val_recall: 0.6939
#
# Epoch 00019: val_loss did not improve from 0.00486
# Epoch 20/100
# 1937/1937 [==============================] - 1s 662us/step - loss: 0.0022 - accuracy: 0.9995 - precision: 0.9286 - recall: 0.7722 - val_loss: 0.0049 - val_accuracy: 0.9992 - val_precision: 0.8718 - val_recall: 0.6939
#
# Epoch 00020: val_loss did not improve from 0.00486
# Epoch 21/100
# 1937/1937 [==============================] - 1s 655us/step - loss: 0.0021 - accuracy: 0.9996 - precision: 0.9337 - recall: 0.8158 - val_loss: 0.0051 - val_accuracy: 0.9991 - val_precision: 0.8256 - val_recall: 0.7245
#
# Epoch 00021: val_loss did not improve from 0.00486
# Epoch 22/100
# 1937/1937 [==============================] - 1s 659us/step - loss: 0.0024 - accuracy: 0.9995 - precision: 0.9284 - recall: 0.7760 - val_loss: 0.0055 - val_accuracy: 0.9991 - val_precision: 0.8767 - val_recall: 0.6531
#
# Epoch 00022: val_loss did not improve from 0.00486
# Epoch 23/100
# 1937/1937 [==============================] - 1s 657us/step - loss: 0.0023 - accuracy: 0.9996 - precision: 0.9339 - recall: 0.8004 - val_loss: 0.0048 - val_accuracy: 0.9992 - val_precision: 0.8816 - val_recall: 0.6837
#
# Epoch 00023: val_loss improved from 0.00486 to 0.00480, saving model to ./model\23-0.0048.hdf5
# Epoch 24/100
# 1937/1937 [==============================] - 1s 657us/step - loss: 0.0017 - accuracy: 0.9996 - precision: 0.9203 - recall: 0.7903 - val_loss: 0.0051 - val_accuracy: 0.9992 - val_precision: 0.8452 - val_recall: 0.7245
#
# Epoch 00024: val_loss did not improve from 0.00480
# Epoch 25/100
# 1937/1937 [==============================] - 1s 654us/step - loss: 0.0021 - accuracy: 0.9995 - precision: 0.8970 - recall: 0.8045 - val_loss: 0.0050 - val_accuracy: 0.9992 - val_precision: 0.8608 - val_recall: 0.6939
#
# Epoch 00025: val_loss did not improve from 0.00480
# Epoch 26/100
# 1937/1937 [==============================] - 1s 656us/step - loss: 0.0021 - accuracy: 0.9996 - precision: 0.9188 - recall: 0.8019 - val_loss: 0.0049 - val_accuracy: 0.9992 - val_precision: 0.9067 - val_recall: 0.6939
#
# Epoch 00026: val_loss did not improve from 0.00480
# Epoch 27/100
# 1937/1937 [==============================] - 1s 663us/step - loss: 0.0024 - accuracy: 0.9995 - precision: 0.9244 - recall: 0.7736 - val_loss: 0.0052 - val_accuracy: 0.9992 - val_precision: 0.8471 - val_recall: 0.7347
#
# Epoch 00027: val_loss did not improve from 0.00480
# Epoch 28/100
# 1937/1937 [==============================] - 1s 659us/step - loss: 0.0018 - accuracy: 0.9996 - precision: 0.9077 - recall: 0.7951 - val_loss: 0.0048 - val_accuracy: 0.9992 - val_precision: 0.9143 - val_recall: 0.6531
#
# Epoch 00028: val_loss improved from 0.00480 to 0.00478, saving model to ./model\28-0.0048.hdf5
# Epoch 29/100
# 1937/1937 [==============================] - 1s 666us/step - loss: 0.0021 - accuracy: 0.9996 - precision: 0.9395 - recall: 0.7961 - val_loss: 0.0052 - val_accuracy: 0.9992 - val_precision: 0.8471 - val_recall: 0.7347
#
# Epoch 00029: val_loss did not improve from 0.00478
# Epoch 30/100
# 1937/1937 [==============================] - 1s 660us/step - loss: 0.0018 - accuracy: 0.9996 - precision: 0.9390 - recall: 0.8225 - val_loss: 0.0053 - val_accuracy: 0.9991 - val_precision: 0.8971 - val_recall: 0.6224
#
# Epoch 00030: val_loss did not improve from 0.00478
# Epoch 31/100
# 1937/1937 [==============================] - 1s 658us/step - loss: 0.0015 - accuracy: 0.9997 - precision: 0.9368 - recall: 0.8375 - val_loss: 0.0057 - val_accuracy: 0.9991 - val_precision: 0.9242 - val_recall: 0.6224
#
# Epoch 00031: val_loss did not improve from 0.00478
# Epoch 32/100
# 1937/1937 [==============================] - 1s 657us/step - loss: 0.0022 - accuracy: 0.9995 - precision: 0.9418 - recall: 0.7653 - val_loss: 0.0050 - val_accuracy: 0.9992 - val_precision: 0.9296 - val_recall: 0.6735
#
# Epoch 00032: val_loss did not improve from 0.00478
# Epoch 33/100
# 1937/1937 [==============================] - 1s 655us/step - loss: 0.0018 - accuracy: 0.9995 - precision: 0.9301 - recall: 0.7935 - val_loss: 0.0051 - val_accuracy: 0.9992 - val_precision: 0.9028 - val_recall: 0.6633
#
# Epoch 00033: val_loss did not improve from 0.00478
# Epoch 34/100
# 1937/1937 [==============================] - 1s 667us/step - loss: 0.0021 - accuracy: 0.9995 - precision: 0.9323 - recall: 0.7475 - val_loss: 0.0052 - val_accuracy: 0.9992 - val_precision: 0.8933 - val_recall: 0.6837
#
# Epoch 00034: val_loss did not improve from 0.00478
# Epoch 35/100
# 1937/1937 [==============================] - 1s 658us/step - loss: 0.0022 - accuracy: 0.9996 - precision: 0.9342 - recall: 0.8084 - val_loss: 0.0048 - val_accuracy: 0.9992 - val_precision: 0.8961 - val_recall: 0.7041
#
# Epoch 00035: val_loss did not improve from 0.00478
# Epoch 36/100
# 1937/1937 [==============================] - 1s 659us/step - loss: 0.0016 - accuracy: 0.9997 - precision: 0.9523 - recall: 0.8216 - val_loss: 0.0049 - val_accuracy: 0.9992 - val_precision: 0.8750 - val_recall: 0.7143
#
# Epoch 00036: val_loss did not improve from 0.00478
# Epoch 37/100
# 1937/1937 [==============================] - 1s 660us/step - loss: 0.0017 - accuracy: 0.9996 - precision: 0.9472 - recall: 0.8256 - val_loss: 0.0055 - val_accuracy: 0.9991 - val_precision: 0.8784 - val_recall: 0.6633
#
# Epoch 00037: val_loss did not improve from 0.00478
# Epoch 38/100
# 1937/1937 [==============================] - 1s 658us/step - loss: 0.0016 - accuracy: 0.9996 - precision: 0.9414 - recall: 0.8575 - val_loss: 0.0051 - val_accuracy: 0.9992 - val_precision: 0.8919 - val_recall: 0.6735
#
# Epoch 00038: val_loss did not improve from 0.00478
# Epoch 39/100
# 1937/1937 [==============================] - 1s 663us/step - loss: 0.0017 - accuracy: 0.9996 - precision: 0.9403 - recall: 0.8285 - val_loss: 0.0057 - val_accuracy: 0.9992 - val_precision: 0.8816 - val_recall: 0.6837
#
# Epoch 00039: val_loss did not improve from 0.00478
# Epoch 40/100
# 1937/1937 [==============================] - 1s 663us/step - loss: 0.0022 - accuracy: 0.9996 - precision: 0.9399 - recall: 0.7999 - val_loss: 0.0049 - val_accuracy: 0.9992 - val_precision: 0.8734 - val_recall: 0.7041
#
# Epoch 00040: val_loss did not improve from 0.00478
# Epoch 41/100
# 1937/1937 [==============================] - 1s 659us/step - loss: 0.0017 - accuracy: 0.9997 - precision: 0.9493 - recall: 0.8219 - val_loss: 0.0054 - val_accuracy: 0.9992 - val_precision: 0.8750 - val_recall: 0.7143
#
# Epoch 00041: val_loss did not improve from 0.00478
# Epoch 42/100
# 1937/1937 [==============================] - 1s 659us/step - loss: 0.0017 - accuracy: 0.9996 - precision: 0.9266 - recall: 0.8174 - val_loss: 0.0055 - val_accuracy: 0.9992 - val_precision: 0.9275 - val_recall: 0.6531
#
# Epoch 00042: val_loss did not improve from 0.00478
# Epoch 43/100
# 1937/1937 [==============================] - 1s 664us/step - loss: 0.0017 - accuracy: 0.9996 - precision: 0.9482 - recall: 0.8135 - val_loss: 0.0054 - val_accuracy: 0.9991 - val_precision: 0.9000 - val_recall: 0.6429
#
# Epoch 00043: val_loss did not improve from 0.00478
# Epoch 44/100
# 1937/1937 [==============================] - 1s 655us/step - loss: 0.0017 - accuracy: 0.9996 - precision: 0.9357 - recall: 0.8155 - val_loss: 0.0050 - val_accuracy: 0.9992 - val_precision: 0.9067 - val_recall: 0.6939
#
# Epoch 00044: val_loss did not improve from 0.00478
# Epoch 45/100
# 1937/1937 [==============================] - 1s 654us/step - loss: 0.0014 - accuracy: 0.9997 - precision: 0.9672 - recall: 0.8417 - val_loss: 0.0050 - val_accuracy: 0.9992 - val_precision: 0.8765 - val_recall: 0.7245
#
# Epoch 00045: val_loss did not improve from 0.00478
# Epoch 46/100
# 1937/1937 [==============================] - 1s 662us/step - loss: 0.0017 - accuracy: 0.9996 - precision: 0.9503 - recall: 0.8218 - val_loss: 0.0052 - val_accuracy: 0.9992 - val_precision: 0.8519 - val_recall: 0.7041
#
# Epoch 00046: val_loss did not improve from 0.00478
# Epoch 47/100
# 1937/1937 [==============================] - 1s 653us/step - loss: 0.0018 - accuracy: 0.9996 - precision: 0.9127 - recall: 0.8009 - val_loss: 0.0052 - val_accuracy: 0.9992 - val_precision: 0.8701 - val_recall: 0.6837
#
# Epoch 00047: val_loss did not improve from 0.00478
# Epoch 48/100
# 1937/1937 [==============================] - 1s 657us/step - loss: 0.0016 - accuracy: 0.9996 - precision: 0.9551 - recall: 0.8256 - val_loss: 0.0051 - val_accuracy: 0.9992 - val_precision: 0.8831 - val_recall: 0.6939
#
# Epoch 00048: val_loss did not improve from 0.00478

# %% [markdown]
# ## 모델의 테스트 데이터에 대한 정확도, 정밀도, 재현율

# %%
print(model.evaluate(X_test, Y_test))
# Out:
# 1336/1336 [==============================] - 1s 431us/step - loss: 0.0019 - accuracy: 0.9995 - precision: 0.9298 - recall: 0.7681
# [0.0019488440593704581, 0.9995318651199341, 0.9298245906829834, 0.7681159377098083]

# %% [markdown]
# ## 모델의 전체 데이터에 대한 정밀도, 재현율

# %%
predict = model.predict(X)

# %%
for i in range(10):
    print('%.10f' % predict[i], Y[i])
# Out:
# 0.0001327693 0.0
# 0.0000463423 0.0
# 0.0001788139 0.0
# 0.0000077418 0.0
# 0.0000170748 0.0
# 0.0000254766 0.0
# 0.0000177463 0.0
# 0.0000168308 0.0
# 0.0000742882 0.0
# 0.0048230290 0.0

# %%
tp = 0
fp = 0
tn = 0
fn = 0
for index, i in enumerate(Y):
    if i == 1.0:
        if (predict[index] > 0.5):
            tp += 1
        else :
            fn += 1
    else:
        if (predict[index] > 0.5):
            fp += 1
        else :
            tn += 1
print(tp, fp, tn, fn)
# Out:
# 389 25 284290 103

# %%
print("precision =\t", tp / (tp + fp))
print("recall =\t", tp / (tp + fn))
# Out:
# precision =	 0.9396135265700483
# recall =	 0.790650406504065

# %%
y_vloss = history.history['val_loss']
y_acc = history.history['accuracy']
x_len = numpy.arange(len(y_vloss))
plt.plot(x_len, y_vloss, 'o', c='red', markersize=3)
plt.plot(x_len, y_acc, 'o', c='blue', markersize=3)
plt.show()
